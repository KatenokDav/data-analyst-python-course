# %%
# Задание вытащить все вакансии СБЕРа с ХХ (у апи есть ограничение в 2000, подумайте как его обойти)
# Вытащите все описания этих вакансий
# Создайте аналогичный vacancy DataFrame только добавьте поле skills
# Переведите даты публикаций в datetime
# Постройте график опубликованных вакансий по датам
# Переведите даты в дни недели, и определите день недели, в который больше всего публикуют вакансий
# Найдите те вакансии с использованием python, которые вам интересны
# Определите по полю skills какие навыки больше всего востребованы для этих вакансий, и
# Постройте график наиболее востребованных вакансий

# %%
import requests
import json
from tqdm.auto import tqdm
from collections import defaultdict
import pickle 
import pandas as pd
import numpy as np
from datetime import datetime,date
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
sber = '3529'
page = 1
num_per_page = 100
moscow = 113
url = f'https://api.hh.ru/vacancies?employer_id={sber}&page={page}&per_page={num_per_page}&area={moscow}'
res = requests.get(url)

# %%
vacancies = res.json()

# %%
all_names = []
all_dates = []
all_skills = []
for i in tqdm(range(vacancies.get('pages'))):
    url = f'https://api.hh.ru/vacancies?employer_id={sber}&page={i}&per_page={num_per_page}&area={moscow}'
    num_pages = vacancies.get('pages')
    vacancy_name = [el.get('name') for el in vacancies.get('items')]
    vacancy_data = [el.get('published_at') for el in vacancies.get('items')]
    vacancy_skills = [el.get('snippet') for el in vacancies.get('items')]
    all_names.extend(vacancy_name)
    all_dates.extend(vacancy_data)
    all_skills.extend(vacancy_skills)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=20.0), HTML(value='')))

# %%
# Создайте аналогичный vacancy DataFrame только добавьте поле skills
vacancy=pd.DataFrame(list(zip(all_names, all_dates,all_skills)),
               columns =['Name', 'Date','Skills'])
vacancy['Quantity']=1
vacancy
# Out:
#                                                    Name  \
# 0                                   Клиентский менеджер
# 1                      Стажер DataScience (SberDevices)
# 2     Территориальный менеджер по пожарной безопасно...
# 3     Менеджер по работе с ключевыми клиентами малог...
# 4                                   Клиентский менеджер
# ...                                                 ...
# 1995                 Клиентский менеджер прямые продажи
# 1996                        Старший клиентский менеджер
# 1997                       Эксперт по подбору персонала
# 1998               Клиентский менеджер (Прямые продажи)
# 1999           Специалист поддержки внутренних клиентов
#
#                           Date  \
# 0     2021-08-11T20:02:43+0300
# 1     2021-07-28T09:35:05+0300
# 2     2021-08-09T08:23:41+0300
# 3     2021-08-12T14:31:24+0300
# 4     2021-07-21T20:35:56+0300
# ...                        ...
# 1995  2021-07-28T15:08:53+0300
# 1996  2021-07-26T09:28:57+0300
# 1997  2021-07-21T10:00:48+0300
# 1998  2021-07-25T18:37:21+0300
# 1999  2021-07-26T11:22:16+0300
#
#                                                  Skills  Quantity
# 0     {'requirement': 'Специалист с образованием от ...         1
# 1     {'requirement': 'Знания в области Deep Learnin...         1
# 2     {'requirement': 'Опыт работы в сфере пожарной ...         1
# 3     {'requirement': 'высшее образование (финансы/б...         1
# 4     {'requirement': 'Имеешь образование от общего ...         1
# ...                                                 ...       ...
# 1995  {'requirement': 'Хочешь развивать навыки публи...         1
# 1996  {'requirement': 'Специалист со средним професс...         1
# 1997  {'requirement': 'Высшее образование. Знание ин...         1
# 1998  {'requirement': 'Хочешь развивать навыки публи...         1
# 1999  {'requirement': 'У тебя высшее или среднее-спе...         1
#
# [2000 rows x 4 columns]

# %%
# Переведите даты публикаций в datetime
vacancy['Date'] = pd.to_datetime(vacancy['Date']).dt.date
vacancy
# Out:
#                                                    Name        Date  \
# 0                                   Клиентский менеджер  2021-08-11
# 1                      Стажер DataScience (SberDevices)  2021-07-28
# 2     Территориальный менеджер по пожарной безопасно...  2021-08-09
# 3     Менеджер по работе с ключевыми клиентами малог...  2021-08-12
# 4                                   Клиентский менеджер  2021-07-21
# ...                                                 ...         ...
# 1995                 Клиентский менеджер прямые продажи  2021-07-28
# 1996                        Старший клиентский менеджер  2021-07-26
# 1997                       Эксперт по подбору персонала  2021-07-21
# 1998               Клиентский менеджер (Прямые продажи)  2021-07-25
# 1999           Специалист поддержки внутренних клиентов  2021-07-26
#
#                                                  Skills  Quantity
# 0     {'requirement': 'Специалист с образованием от ...         1
# 1     {'requirement': 'Знания в области Deep Learnin...         1
# 2     {'requirement': 'Опыт работы в сфере пожарной ...         1
# 3     {'requirement': 'высшее образование (финансы/б...         1
# 4     {'requirement': 'Имеешь образование от общего ...         1
# ...                                                 ...       ...
# 1995  {'requirement': 'Хочешь развивать навыки публи...         1
# 1996  {'requirement': 'Специалист со средним професс...         1
# 1997  {'requirement': 'Высшее образование. Знание ин...         1
# 1998  {'requirement': 'Хочешь развивать навыки публи...         1
# 1999  {'requirement': 'У тебя высшее или среднее-спе...         1
#
# [2000 rows x 4 columns]

# %%
# Постройте график опубликованных вакансий по датам
vacancy_1 = vacancy.groupby(['Date'])['Quantity'].sum()
vacancy_1.plot(kind='bar',title='Динамика опубликованных вакансий по датам')
plt.xlabel('Дата')
plt.ylabel('Количество')
# Out:
# Text(0, 0.5, 'Количество')

# %%
# Переведите даты в дни недели, и определите день недели, в который больше всего публикуют вакансий
vacancy['Date'] = pd.to_datetime(vacancy['Date'])
vacancy['day_of_week'] = vacancy['Date'].dt.day_name()
vacancy_2 = vacancy.groupby(['day_of_week'])['Quantity'].sum()
vacancy_2
# Out:
# day_of_week
# Friday       240
# Monday       380
# Saturday      20
# Sunday       100
# Thursday     480
# Tuesday      320
# Wednesday    460
# Name: Quantity, dtype: int64

# %%
# Найдите те вакансии с использованием python, которые вам интересны
vacancy_like = vacancy.loc[(vacancy.Name.str.contains(r'Data Analyst|Дата аналитик$'))]
vacancy_like
# Out:
#                                Name       Date  \
# 17    Data Analyst (Junior|Junior+) 2021-07-27
# 117   Data Analyst (Junior|Junior+) 2021-07-27
# 217   Data Analyst (Junior|Junior+) 2021-07-27
# 317   Data Analyst (Junior|Junior+) 2021-07-27
# 417   Data Analyst (Junior|Junior+) 2021-07-27
# 517   Data Analyst (Junior|Junior+) 2021-07-27
# 617   Data Analyst (Junior|Junior+) 2021-07-27
# 717   Data Analyst (Junior|Junior+) 2021-07-27
# 817   Data Analyst (Junior|Junior+) 2021-07-27
# 917   Data Analyst (Junior|Junior+) 2021-07-27
# 1017  Data Analyst (Junior|Junior+) 2021-07-27
# 1117  Data Analyst (Junior|Junior+) 2021-07-27
# 1217  Data Analyst (Junior|Junior+) 2021-07-27
# 1317  Data Analyst (Junior|Junior+) 2021-07-27
# 1417  Data Analyst (Junior|Junior+) 2021-07-27
# 1517  Data Analyst (Junior|Junior+) 2021-07-27
# 1617  Data Analyst (Junior|Junior+) 2021-07-27
# 1717  Data Analyst (Junior|Junior+) 2021-07-27
# 1817  Data Analyst (Junior|Junior+) 2021-07-27
# 1917  Data Analyst (Junior|Junior+) 2021-07-27
#
#                                                  Skills  Quantity day_of_week
# 17    {'requirement': 'Понимание теории баз данных. ...         1     Tuesday
# 117   {'requirement': 'Понимание теории баз данных. ...         1     Tuesday
# 217   {'requirement': 'Понимание теории баз данных. ...         1     Tuesday
# 317   {'requirement': 'Понимание теории баз данных. ...         1     Tuesday
# 417   {'requirement': 'Понимание теории баз данных. ...         1     Tuesday
# 517   {'requirement': 'Понимание теории баз данных. ...         1     Tuesday
# 617   {'requirement': 'Понимание теории баз данных. ...         1     Tuesday
# 717   {'requirement': 'Понимание теории баз данных. ...         1     Tuesday
# 817   {'requirement': 'Понимание теории баз данных. ...         1     Tuesday
# 917   {'requirement': 'Понимание теории баз данных. ...         1     Tuesday
# 1017  {'requirement': 'Понимание теории баз данных. ...         1     Tuesday
# 1117  {'requirement': 'Понимание теории баз данных. ...         1     Tuesday
# 1217  {'requirement': 'Понимание теории баз данных. ...         1     Tuesday
# 1317  {'requirement': 'Понимание теории баз данных. ...         1     Tuesday
# 1417  {'requirement': 'Понимание теории баз данных. ...         1     Tuesday
# 1517  {'requirement': 'Понимание теории баз данных. ...         1     Tuesday
# 1617  {'requirement': 'Понимание теории баз данных. ...         1     Tuesday
# 1717  {'requirement': 'Понимание теории баз данных. ...         1     Tuesday
# 1817  {'requirement': 'Понимание теории баз данных. ...         1     Tuesday
# 1917  {'requirement': 'Понимание теории баз данных. ...         1     Tuesday

# %%
# Постройте график наиболее востребованных вакансий
vacancy_3 = vacancy.groupby('Name').sum().reset_index()
vacancy_3 = vacancy_3.sort_values(by=['Quantity'],ascending =[False])
vacancy_4=vacancy_3.loc[vacancy_3['Quantity'] >= 21]
sns.barplot(data=vacancy_4,x='Quantity',y='Name')
# Out:
# <AxesSubplot:xlabel='Quantity', ylabel='Name'>

# %%
# Определите по полю skills какие навыки больше всего востребованы для этих вакансий
